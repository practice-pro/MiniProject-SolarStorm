# %% [markdown]
# <a href="https://colab.research.google.com/github/practice-pro/MiniProject-SolarStorm/blob/main/Modelkp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=c01b6b284215c37887d41107bb5e6aa09768f7ca0f9c748ef8d1608e81ab137e
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
import regex as re
import wget
import os

# %%
import datetime

sd = datetime.datetime(2023, 5,15).strftime("%Y%m%d")
ed = datetime.datetime(2023,5,15).strftime("%Y%m%d")

# %%
import pandas as pd
ls=pd.date_range(sd,ed)

# %%
dates=[dt.strftime("%Y%m%d") for dt in ls]

# %%
years={date[:4] for date in dates}
months={date[4:6] for date in dates}

# %%
txt=""
for year in years:
    for month in months:
        base='https://www.ngdc.noaa.gov/dscovr/data/'+year+'/'+month+'/'
        txt+=requests.get(base).text

# %%
urllist=[]

# %%
for date in dates:
    base='https://www.ngdc.noaa.gov/dscovr/data/'+date[:4]+'/'+date[4:6]+'/'
    x=re.search(str("oe_m1m_dscovr_s"+date+"000000_"), txt).start()
    url=base+txt[x: x+71]
    print(date,": ",url)
    urllist.append(url[46:])
    wget.download(url)
# Out:
# 20230515 :  https://www.ngdc.noaa.gov/dscovr/data/2023/05/oe_m1m_dscovr_s20230515000000_e20230515235959_p20230516021800_pub.nc.gz

# %%
import numpy as np
import torch
import xarray as xr

# %%
l=len(urllist)

# %%
magdata=[]

# %%
for i in range(0,l):
  ds=xr.open_dataset('/content/'+urllist[i])
  df=ds.to_dataframe()
  actualdf=df.dropna()
  df_len=len(actualdf)
  for j in range(0,df_len,180):
   bx_gse_hour=np.nanmean(np.array(actualdf['bx_gse'][j:j+180]))
   by_gse_hour=np.nanmean(np.array(actualdf['by_gse'][j:j+180]))
   bz_gse_hour=np.nanmean(np.array(actualdf['bz_gse'][j:j+180]))
   magdata.append([bx_gse_hour,by_gse_hour,bz_gse_hour])

# %%
magdata_numpy=np.array(magdata)

# %%
magdata_torch= torch.from_numpy(magdata_numpy)

# %%
import torch.nn as nn
from argparse import ArgumentParser, Namespace
import enum
from pathlib import Path
from typing import Dict
import matplotlib.pyplot as plt

# %%
class Seq2Seq(nn.Module):
    def __init__(
        self,
        input_dim: int,
        hidden_dim: int,
        output_dim: int,
        num_layers: int) -> None:
        super(Seq2Seq, self).__init__()

        self.rnn = nn.GRU(input_dim, hidden_dim, num_layers, batch_first=True)
        self.dnn = nn.Sequential(
            nn.Linear(hidden_dim, output_dim)
        )

    def forward(self, seq: torch.Tensor) -> torch.Tensor:
        # seq: [bs, seq_len, input_dim]
        output, hn = self.rnn(seq)
        output = self.dnn(output)
        return output

# %%
model2 = Seq2Seq(1,3,1,3)
model2.load_state_dict(torch.load("/content/drive/MyDrive/proton_to_forecast.pt"))
# Out:
# <All keys matched successfully>

# %%
m3=magdata_torch.unsqueeze(-1)

# %%
kpindex=model2(m3.float())

# %%
knp=kpindex.detach().numpy()

# %%
lp=len(knp)
day1=[]
day2=[]
day3=[]
for i in range(lp):
  day1.append(knp[i][0][0])
  day2.append(knp[i][1][0])
  day3.append(knp[i][2][0])

# %%
plt.title("Day1")
plt.xlabel("3-hr intervals")
plt.ylabel("K-DSCOVR index")
plt.plot(day1)

# %%
plt.title("Day2")
plt.xlabel("3-hr intervals")
plt.ylabel("K-DSCOVR index")
plt.plot(day2)

# %%
plt.title("Day3")
plt.xlabel("3-hr intervals")
plt.ylabel("K-DSCOVR index")
plt.plot(day3)
